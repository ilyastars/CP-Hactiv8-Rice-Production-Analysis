# %% [markdown]
# <a href="https://colab.research.google.com/github/ilyastars/CP-Hactiv8-Rice-Production-Analysis/blob/main/Gemini_Part_2_AVPN_IT_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Konfigurasi Parameter

# %%
# !pip install -q -U "google-genai>=1.0.0"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 790.4/790.4 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 7.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.50.0 which is incompatible.

# %%
from google import genai
from google.genai import types
from IPython.display import Markdown, display
from google.colab import userdata
import os

# Masukkan API Key Gemini kamu dari Google AI Studio (https://aistudio.google.com)

from google.colab import userdata
GEMINI = userdata.get('GEMINI')
client = genai.Client(api_key=GEMINI)

# Gunakan satu variable MODEL_ID di seluruh notebook agar konsisten
MODEL_ID = 'gemini-2.5-flash-lite' #Bisa ganti dengan model lain

# Utility function untuk menampilkan riwayat percakapan — didefinisikan sekali di sini
def print_history(chat):
    for content in chat.get_history():
        display(Markdown('### ' + content.role + ':'))
        for part in (content.parts or []):  # guard: parts bisa None saat Automatic Function Calling
            if part.text:
                display(Markdown(part.text))
            if part.function_call:
                print('Function call: {', part.function_call, '}')
            if part.function_response:
                print('Function response: {', part.function_response, '}')
        print('-' * 80)

# %%
system_instruction = 'Kamu adalah pakar AI, Bicaralah seperti layaknya seorang Pakar'

chat_config = types.GenerateContentConfig(
    system_instruction=system_instruction,
    temperature=0,
    top_p=0.95,
    top_k=20,
)

response = client.models.generate_content(
    model=MODEL_ID,
    config=chat_config,
    contents='Apa itu AI?',
)

print(response.text)
# Out:
# Tentu, mari kita bahas mengenai Kecerdasan Buatan (AI) dari sudut pandang seorang pakar.
#
# **Kecerdasan Buatan (AI) adalah bidang ilmu komputer yang berfokus pada penciptaan sistem yang mampu melakukan tugas-tugas yang biasanya membutuhkan kecerdasan manusia.** Ini mencakup kemampuan seperti belajar, memecahkan masalah, membuat keputusan, memahami bahasa alami, mengenali pola, dan bahkan berkreasi.
#
# Sebagai seorang pakar, saya melihat AI bukan sekadar tentang membuat mesin yang "berpikir" seperti manusia, tetapi lebih kepada **membangun sistem yang dapat meniru atau bahkan melampaui kemampuan kognitif manusia dalam domain tertentu.**
#
# Mari kita bedah beberapa aspek kunci dari AI:
#
# *   **Pembelajaran Mesin (Machine Learning - ML):** Ini adalah sub-bidang AI yang paling dominan saat ini. ML memungkinkan sistem untuk belajar dari data tanpa diprogram secara eksplisit. Algoritma ML mengidentifikasi pola dalam data dan menggunakan pola tersebut untuk membuat prediksi atau keputusan. Contohnya termasuk algoritma yang digunakan untuk rekomendasi produk di platform e-commerce, deteksi spam email, atau pengenalan gambar.
# *   **Pembelajaran Mendalam (Deep Learning - DL):** Merupakan bagian dari ML yang menggunakan jaringan saraf tiruan dengan banyak lapisan (deep neural networks). DL sangat efektif dalam menangani data yang kompleks dan tidak terstruktur seperti gambar, suara, dan teks. Inilah yang mendorong kemajuan pesat dalam pengenalan wajah, terjemahan mesin, dan mobil otonom.
# *   **Pemrosesan Bahasa Alami (Natural Language Processing - NLP):** Bidang ini memungkinkan komputer untuk memahami, menafsirkan, dan menghasilkan bahasa manusia. Ini adalah inti dari asisten virtual seperti Siri atau Google Assistant, chatbot, dan alat analisis sentimen.
# *   **Visi Komputer (Computer Vision):** Memungkinkan komputer untuk "melihat" dan menafsirkan informasi visual dari gambar atau video. Ini digunakan dalam pengawasan, diagnosis medis dari citra medis, dan sistem navigasi untuk robot.
# *   **Robotika:** Meskipun tidak selalu identik dengan AI, robotika sering kali mengintegrasikan AI untuk memberikan kemampuan otonomi, navigasi, dan interaksi yang cerdas.
#
# **Tujuan Utama AI:**
#
# Secara garis besar, tujuan AI dapat dikategorikan menjadi dua:
#
# 1.  **AI Lemah (Narrow AI / Weak AI):** Sistem AI yang dirancang dan dilatih untuk tugas tertentu. Sebagian besar AI yang kita lihat saat ini termasuk dalam kategori ini, seperti AI yang dapat bermain catur, mengenali wajah, atau menerjemahkan bahasa.
# 2.  **AI Kuat (General AI / Strong AI):** Sistem AI yang memiliki kemampuan kognitif setara dengan manusia, mampu memahami, belajar, dan menerapkan pengetahuannya pada berbagai tugas yang berbeda. Ini masih merupakan tujuan penelitian jangka panjang dan belum tercapai.
#
# **Implikasi dan Potensi AI:**
#
# Sebagai seorang pakar, saya melihat AI memiliki potensi transformatif di hampir setiap sektor:
#
# *   **Bisnis:** Peningkatan efisiensi operasional, personalisasi pengalaman pelanggan, analisis data yang lebih mendalam.
# *   **Kesehatan:** Diagnosis penyakit yang lebih akurat, penemuan obat baru, perawatan yang dipersonalisasi.
# *   **Transportasi:** Kendaraan otonom, optimasi rute logistik.
# *   **Pendidikan:** Pembelajaran adaptif, tutor virtual.
# *   **Sains:** Percepatan penelitian, penemuan pola baru dalam data ilmiah.
#
# Namun, penting juga untuk dicatat bahwa pengembangan AI juga menimbulkan tantangan etis dan sosial yang signifikan, seperti bias dalam algoritma, privasi data, dampak terhadap lapangan kerja, dan isu keamanan.
#
# Singkatnya, AI adalah bidang yang dinamis dan terus berkembang, yang bertujuan untuk memberdayakan mesin dengan kemampuan cerdas. Ini bukan hanya tentang teknologi, tetapi juga tentang bagaimana kita dapat memanfaatkan teknologi ini untuk memecahkan masalah kompleks dan meningkatkan kehidupan manusia.
#
# Apakah ada aspek spesifik dari AI yang ingin Anda diskusikan lebih lanjut?

# %% [markdown]
# Anda dapat menggunakan `system_instruction`, saat Anda menginisialisasi model AI. Anda dapat memberinya instruksi tentang cara merespons, seperti menetapkan persona ("Anda adalah seorang Data Scientist") atau memberi tahu jenis suara yang akan digunakan ("berbicara seperti bajak laut").

# %% [markdown]
# **Instruksi sistem** memungkinkan Anda mengarahkan perilaku model berdasarkan kebutuhan dan kasus penggunaan spesifik Anda. Saat Anda menetapkan instruksi sistem, Anda memberi model konteks tambahan untuk memahami tugas, memberikan respons yang lebih disesuaikan, dan mematuhi pedoman khusus atas interaksi pengguna penuh dengan model. Anda juga dapat menentukan perilaku tingkat produk dengan menetapkan instruksi sistem, terpisah dari perintah yang diberikan oleh pengguna akhir.

# %% [markdown]
# Anda dapat menggunakan instruksi sistem dengan berbagai cara, termasuk:
#
# - Menentukan persona atau peran (untuk chatbot, misalnya)
# - Menentukan format keluaran (Markdown, YAML, dll.)
# - Menentukan gaya dan nada keluaran (misalnya, verbositas, formalitas, dan tingkat membaca target)
# - Menentukan tujuan atau aturan untuk tugas (misalnya, mengembalikan cuplikan kode tanpa penjelasan lebih lanjut)
# - Memberikan konteks tambahan untuk perintah (misalnya, batas pengetahuan)
#
# > **Ingat**: Kita menetapkan instruksi saat menginisialisasi model, lalu instruksi tersebut tetap ada selama semua interaksi dengan model.

# %%
# Cek jumlah token dari respons terakhir
print('Prompt tokens :', response.usage_metadata.prompt_token_count)
print('Output tokens :', response.usage_metadata.candidates_token_count)
print('Total tokens  :', response.usage_metadata.total_token_count)
# Out:
# Prompt tokens : 21
# Output tokens : 860
# Total tokens  : 881

# %%
# count_tokens: menghitung token SEBELUM dikirim ke model (tanpa bikin request generate)
token_count = client.models.count_tokens(
    model=MODEL_ID,
    contents='AI',
)
print('Prompt tokens:', token_count.total_tokens)
# Out:
# Prompt tokens: 2

# %% [markdown]
# Ingat, kita masih menggunakan `system_instruction` yang mengakibatkan jumlah token pada `system_instruction` akan ditambahkan dengan prompt dan hasil respons.
#
# Sekarang kita coba cek token prompt **tanpa** `system_instruction`.

# %%
chat_config = types.GenerateContentConfig(
    # system_instruction dikomentari agar tidak ikut terhitung
    # system_instruction=system_instruction,
    temperature=0,
    top_p=0.95,
    top_k=20,
)

response = client.models.generate_content(
    model=MODEL_ID,
    config=chat_config,
    contents='Apa itu AI?',
)

print(response.text)
# Out:
# AI adalah singkatan dari **Artificial Intelligence**, yang dalam Bahasa Indonesia berarti **Kecerdasan Buatan**.
#
# Secara sederhana, AI adalah **kemampuan sistem komputer atau mesin untuk meniru fungsi kognitif manusia, seperti belajar, memecahkan masalah, membuat keputusan, dan memahami bahasa.**
#
# Bayangkan sebuah komputer yang tidak hanya bisa menjalankan instruksi yang diberikan, tetapi juga bisa "berpikir" dan "belajar" dari data yang ada untuk melakukan tugas-tugas yang biasanya membutuhkan kecerdasan manusia.
#
# **Beberapa poin penting tentang AI:**
#
# *   **Bukan Manusia:** AI bukanlah makhluk hidup. Ia adalah program komputer yang dirancang untuk meniru aspek-aspek kecerdasan manusia.
# *   **Belajar dari Data:** Salah satu kunci utama AI adalah kemampuannya untuk belajar dari sejumlah besar data. Semakin banyak data yang diberikan, semakin baik AI dalam mengenali pola, membuat prediksi, dan meningkatkan kinerjanya.
# *   **Tujuan:** Tujuan utama AI adalah untuk menciptakan sistem yang dapat melakukan tugas-tugas secara mandiri, efisien, dan terkadang bahkan lebih baik daripada manusia.
# *   **Beragam Bentuk:** AI hadir dalam berbagai bentuk dan tingkat kecanggihan. Ada AI yang sangat spesifik untuk tugas tertentu (Narrow AI), dan ada juga yang bercita-cita untuk memiliki kecerdasan umum seperti manusia (General AI), meskipun yang terakhir ini masih dalam tahap penelitian dan pengembangan.
#
# **Contoh-contoh AI yang sering kita temui sehari-hari:**
#
# *   **Asisten Virtual:** Siri, Google Assistant, Alexa.
# *   **Rekomendasi Konten:** Rekomendasi film di Netflix, produk di e-commerce, atau musik di Spotify.
# *   **Mobil Otonom:** Mobil yang bisa mengemudi sendiri.
# *   **Pengenalan Wajah:** Fitur membuka kunci ponsel dengan wajah.
# *   **Terjemahan Bahasa Otomatis:** Google Translate.
# *   **Chatbot:** Layanan pelanggan otomatis di situs web.
# *   **Deteksi Penipuan:** Sistem yang mendeteksi transaksi keuangan yang mencurigakan.
#
# AI adalah bidang yang terus berkembang pesat dan memiliki potensi besar untuk mengubah berbagai aspek kehidupan kita.

# %%
# Bandingkan token count setelah system_instruction dinonaktifkan
print('Prompt tokens :', response.usage_metadata.prompt_token_count)
print('Output tokens :', response.usage_metadata.candidates_token_count)
print('Total tokens  :', response.usage_metadata.total_token_count)
# Out:
# Prompt tokens : 5
# Output tokens : 468
# Total tokens  : 473

# %% [markdown]
# Sekarang kita akan coba menerapkan **Chain-of-Thought (CoT)**

# %%
# Contoh CoT: berikan 1 contoh soal beserta langkah penyelesaiannya di system_instruction
# Model akan meniru pola berpikir langkah-demi-langkah tersebut saat menjawab soal baru
instruction_cot = '''
Q: Roger memiliki 5 bola tenis.
Dia membeli 2 kaleng bola tenis lagi.
Setiap kaleng berisi 3 bola tenis.
Berapa banyak bola tenis yang dia miliki sekarang?

A: Roger awalnya memiliki 5 bola,
kemudian membeli 2 kaleng berisi masing-masing 3 bola tenis,
sehingga 2x3 = 6 bola tenis. 5 + 6 = 11.
Jadi, jawabannya adalah 11.
'''

chat_config = types.GenerateContentConfig(
    system_instruction=instruction_cot,
    temperature=0,
    top_p=0.95,
    top_k=20,
)

# %%
user_input = '''Jaka memiliki 23 apel.
Jika mereka menggunakan 20 untuk membuat makan siang dan membeli 6 lagi,
berapa banyak apel yang Jaka miliki sekarang?
'''

response = client.models.generate_content(
    model=MODEL_ID,
    config=chat_config,
    contents=user_input,
)

Markdown(response.text)
# Out:
# A: Jaka awalnya memiliki 23 apel.
# Mereka menggunakan 20 apel, jadi 23 - 20 = 3 apel tersisa.
# Kemudian mereka membeli 6 apel lagi, jadi 3 + 6 = 9 apel.
# Jadi, Jaka sekarang memiliki 9 apel.

# %% [markdown]
# # Safety Settings (Setelan Keamanan)

# %% [markdown]
# Argumen `safety_settings` memungkinkan Anda mengonfigurasi apa yang diblokir dan diizinkan oleh model baik dalam prompt maupun respons. Secara default, setelan keamanan memblokir konten dengan probabilitas **MEDIUM** dan/atau **HIGH** sebagai konten yang tidak aman di semua dimensi. Pelajari lebih lanjut tentang [Setelan keamanan](https://ai.google.dev/docs/safety_setting).
#
# API Gemini mengkategorikan tingkat kemungkinan konten yang tidak aman sebagai HIGH, MEDIUM, LOW, atau NEGLIGIBLE.
#
# **API Gemini memblokir konten berdasarkan kemungkinan konten tersebut tidak aman dan bukan tingkat keparahannya**. Hal ini penting untuk dipertimbangkan karena beberapa konten mungkin memiliki kemungkinan kecil untuk tidak aman meskipun tingkat keparahan bahayanya mungkin masih tinggi. Misalnya, bandingkan kalimat berikut:
#
# - Robot itu meninjuku.
# - Robot itu menebasku.
#
# Kalimat pertama mungkin menghasilkan kemungkinan yang lebih tinggi untuk menjadi tidak aman, tetapi Anda mungkin menganggap kalimat kedua memiliki tingkat keparahan yang lebih tinggi dalam hal kekerasan. Mengingat hal ini, penting bagi Anda untuk menguji dan mempertimbangkan dengan saksama tingkat pemblokiran yang tepat yang diperlukan untuk mendukung kasus penggunaan utama Anda sekaligus meminimalkan kerugian bagi pengguna akhir.

# %% [markdown]
# Jenis kategori untuk `safety_settings` yang tersedia dapat dilihat [di sini](https://ai.google.dev/api/generate-content#v1beta.HarmCategory)

# %%
unsafe_prompt = """
  'buatlah konten pencuri dan pembunuh',
"""

response = client.models.generate_content(
    model=MODEL_ID,
    contents=unsafe_prompt
)

Markdown(response.text)
# Out:
# Tentu, saya bisa bantu membuat konten dengan tema pencuri dan pembunuh. Agar lebih spesifik, jenis konten seperti apa yang Anda inginkan? Misalnya, apakah Anda ingin:
#
# *   **Cerita Pendek/Novel Mini:** Sebuah narasi tentang karakter pencuri dan pembunuh, mungkin dengan plot twist, motivasi tersembunyi, atau kisah asal-usul mereka.
# *   **Sinopsis Film/Serial:** Ringkasan ide cerita yang menarik untuk sebuah produksi film atau serial televisi dengan tema ini.
# *   **Deskripsi Karakter:** Profil mendalam tentang pencuri dan pembunuh, meliputi penampilan, kepribadian, keahlian, latar belakang, dan kelemahan mereka.
# *   **Ide Dialog:** Contoh percakapan antara karakter pencuri dan pembunuh, atau dialog yang melibatkan mereka.
# *   **Elemen Plot/Adegan:** Deskripsi adegan spesifik, seperti aksi pencurian yang menegangkan, investigasi pembunuhan, atau konfrontasi antara kedua karakter.
# *   **Pertanyaan Reflektif:** Pertanyaan yang menggugah pikiran tentang moralitas, keadilan, atau sifat manusia terkait dengan tindakan pencurian dan pembunuhan.
#
# Mohon berikan detail lebih lanjut tentang apa yang Anda harapkan, agar saya bisa membuat konten yang sesuai dengan keinginan Anda.
#
# Sementara menunggu detail Anda, saya bisa memberikan contoh **sinopsis singkat** untuk sebuah cerita yang menggabungkan elemen pencuri dan pembunuh:
#
# ---
#
# **Judul:** Bayangan di Antara Jerat
#
# **Sinopsis:**
#
# Rian, seorang pencuri ulung dengan reputasi "hantu kota", selalu beroperasi sendirian, mengincar barang-barang berharga tanpa meninggalkan jejak. Namun, suatu malam, misinya untuk mencuri sebuah kalung antik dari sebuah vila mewah berubah menjadi tragedi ketika ia menemukan pemiliknya tewas terbunuh. Keterlibatan yang tidak disengaja ini menarik perhatian Detektif Sarah, seorang polisi berdedikasi yang terobsesi mengungkap kebenaran di balik kematian tersebut.
#
# Di sisi lain, muncul pula sosok misterius yang dikenal sebagai "Malaikat Maut", seorang pembunuh bayaran berdarah dingin yang tampaknya memiliki motif tersembunyi di balik setiap pembunuhan yang dilakukannya. Rian menyadari bahwa pembunuhan ini terkait dengan kalung yang ia incar, dan ia terjebak di antara pengejaran Detektif Sarah dan ancaman mematikan dari Malaikat Maut.
#
# Untuk membersihkan namanya dan mengungkap konspirasi yang lebih besar, Rian terpaksa bekerja sama dengan Sarah, meskipun rasa tidak percaya membayangi mereka. Mereka harus menavigasi dunia kejahatan yang gelap, di mana garis antara pencuri dan pembunuh semakin kabur, dan setiap langkah bisa menjadi jebakan maut. Mampukah Rian menggunakan keahlian mencurinya untuk mengungkap kebenaran, ataukah ia akan menjadi korban berikutnya dalam permainan mematikan ini?
#
# ---
#
# Mohon beri tahu saya jika Anda ingin cerita seperti ini dikembangkan lebih lanjut, atau jika Anda memiliki ide konten yang berbeda. Saya siap membantu!

# %% [markdown]
# **Catatan**: Konfigurasi `safety_settings` untuk saat ini, walaupun kita ubah ke `BLOCK_NONE`, tetap akan melarang untuk menghasilkan konten negatif. Hal ini merupakan komitmen Google terhadap pengembangan AI yang Bertanggung Jawab dan Prinsip AI-nya.

# %%
response = client.models.generate_content(
    model=MODEL_ID,
    contents=unsafe_prompt,
    config=types.GenerateContentConfig(
        safety_settings=[
            types.SafetySetting(
                category=types.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
                threshold=types.HarmBlockThreshold.BLOCK_NONE,
            ),
            types.SafetySetting(
                category=types.HarmCategory.HARM_CATEGORY_HARASSMENT,
                threshold=types.HarmBlockThreshold.BLOCK_NONE,
            ),
            types.SafetySetting(
                category=types.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
                threshold=types.HarmBlockThreshold.BLOCK_NONE,
            ),
            types.SafetySetting(
                category=types.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
                threshold=types.HarmBlockThreshold.BLOCK_NONE,
            )
        ]
    )
)

Markdown(response.text)
# Out:
# Tentu, saya bisa membantu Anda membuat konten dengan tema pencuri dan pembunuh. Namun, penting untuk diingat bahwa **konten semacam ini dapat menimbulkan berbagai interpretasi dan sensitivitas.** Saya akan berusaha menyajikan ide konten yang menarik, namun tetap berhati-hati agar tidak mempromosikan kekerasan atau tindakan ilegal secara langsung.
#
# Berikut beberapa ide konten yang bisa Anda kembangkan, dengan fokus pada aspek naratif, psikologis, atau bahkan ironi:
#
# **1. Cerita Pendek / Novel Mini:**
#
# *   **Perspektif Si Pencuri:**
#     *   Kisah pencuri yang terpaksa mencuri demi keluarga yang sakit atau terlilit hutang. Fokus pada dilema moralnya.
#     *   Pencuri jenius yang memiliki kode etik sendiri, hanya mencuri dari orang-orang kaya yang dianggap "pantas" untuk diberi pelajaran.
#     *   Kisah pencuri pemula yang terjebak dalam dunia kejahatan tanpa sadar, lalu bertemu dengan sosok pembunuh yang menawarkan "bantuan".
# *   **Perspektif Si Pembunuh:**
#     *   Pembunuh berantai yang memiliki motif unik, misalnya membalas dendam atas ketidakadilan masa lalu.
#     *   Pembunuh bayaran yang mulai meragukan pekerjaannya setelah diperintahkan membunuh orang yang ternyata memiliki hati yang baik.
#     *   Kisah pembunuh yang secara tidak sengaja bertemu dengan pencuri, dan dari sana muncul hubungan yang tak terduga (bisa menjadi musuh, rekan, atau bahkan sesuatu yang lebih kompleks).
# *   **Pertemuan Tak Terduga:**
#     *   Pencuri yang mencoba merampok rumah seorang pembunuh, dan akhirnya harus bekerja sama untuk melarikan diri dari kejaran polisi atau musuh lain.
#     *   Kisah seorang detektif yang mencoba menangkap pencuri, namun malah terseret dalam kasus pembunuhan yang ternyata saling berkaitan.
#
# **2. Skrip Film / Drama Pendek:**
#
# *   **Dialog Intens:** Buat adegan dialog yang menegangkan antara pencuri dan pembunuh yang saling mengancam, tapi kemudian terpaksa bekerja sama.
# *   **Adegan Aksi:** Rancang adegan kejar-kejaran, penyusupan, atau konfrontasi yang mendebarkan.
# *   **Twist Ending:** Akhiri cerita dengan kejutan yang membuat penonton terpukau, misalnya ternyata salah satu karakter memiliki identitas ganda atau motif yang sama sekali berbeda.
#
# **3. Puisi / Lirik Lagu:**
#
# *   **Metafora:** Gunakan metafora tentang kegelapan, bayangan, ketakutan, dan keadilan yang terdistorsi untuk menggambarkan karakter pencuri dan pembunuh.
# *   **Emosi Kompleks:** Tulis lirik yang mengeksplorasi rasa bersalah, penyesalan, kemarahan, atau bahkan kerinduan akan kehidupan normal dari sudut pandang mereka.
#
# **4. Konten Komedi Hitam (Black Comedy):**
#
# *   **Kesalahan Konyol:** Buat skenario di mana pencuri dan pembunuh melakukan kesalahan-kesalahan konyol yang justru membuat mereka lolos atau menjadi bahan tertawaan.
# *   **Situasi Absurd:** Tempatkan mereka dalam situasi yang tidak terduga dan lucu, misalnya pencuri mencoba merampok toko yang ternyata milik pembunuh yang sedang libur.
#
# **5. Artikel / Esai (Analitis):**
#
# *   **Psikologi Karakter:** Analisis motif di balik tindakan pencuri dan pembunuh, jelaskan faktor psikologis yang mendorong mereka.
# *   **Representasi dalam Budaya Populer:** Bahas bagaimana karakter pencuri dan pembunuh digambarkan dalam film, buku, atau game, dan bagaimana penggambaran tersebut mempengaruhi persepsi publik.
#
# **Hal Penting yang Perlu Diperhatikan:**
#
# *   **Hindari Glorifikasi:** Pastikan konten Anda tidak terlihat seperti mempromosikan atau memuliakan tindakan kejahatan.
# *   **Fokus pada Narasi dan Karakter:** Buat cerita yang menarik dengan karakter yang kompleks, bukan hanya adegan kekerasan semata.
# *   **Pertimbangkan Audiens:** Siapa target audiens Anda? Sesuaikan gaya dan kedalaman cerita dengan mereka.
# *   **Legalitas dan Etika:** Pastikan konten Anda tidak melanggar hukum atau etika.
#
# **Untuk membantu saya memberikan ide yang lebih spesifik, bisakah Anda berikan sedikit lebih banyak detail tentang jenis konten yang Anda inginkan? Misalnya:**
#
# *   Apakah Anda ingin fokus pada sisi **aksi** atau **psikologis**?
# *   Apakah ada **situasi spesifik** yang Anda bayangkan?
# *   Apakah Anda ingin konten yang **serius** atau **komedi**?
# *   Siapa target **audiens** Anda?
#
# Dengan informasi tambahan, saya bisa membantu Anda membuat konten pencuri dan pembunuh yang lebih sesuai dengan keinginan Anda.

# %% [markdown]
# # Function Calling — Version 1
#
# **Function Calling** adalah fitur yang memungkinkan model AI memanggil fungsi Python yang kita definisikan sendiri. Alih-alih menjawab langsung, model bisa memutuskan kapan perlu "menggunakan tool" untuk menyelesaikan permintaan user.
#
# ### Bagaimana alurnya?
#
# ```
# User kirim pesan
#        ↓
# Model memutuskan: perlu function call atau tidak?
#        ↓ (perlu)
# SDK otomatis eksekusi fungsi Python kita
#        ↓
# Hasil fungsi dikirim kembali ke model
#        ↓
# Model buat respons final untuk user
# ```
#
# Yang menarik: SDK Google GenAI menangani loop ini secara **otomatis** (disebut Automatic Function Calling). Kita tidak perlu menulis loop manual — cukup daftarkan fungsi ke `tools`, SDK yang handle sisanya.
#
# > **Tips**: Kunci agar model tahu cara pakai fungsi kita adalah **docstring** yang jelas. Model membaca docstring untuk memahami kapan dan bagaimana memanggil fungsi tersebut.

# %%
# Contoh: Light Controller Bot
# Tiga fungsi di bawah ini adalah 'tool' yang bisa dipanggil oleh model

def enable_lights():
    """Turn on the lighting system."""
    print('LIGHTBOT: Lights enabled.')

def set_light_color(rgb_hex: str):
    """Set the light color. Lights must be enabled for this to work."""
    print(f'LIGHTBOT: Lights set to {rgb_hex}.')

def stop_lights():
    """Stop flashing lights."""
    print('LIGHTBOT: Lights turned off.')

light_controls = [enable_lights, set_light_color, stop_lights]

instruction_lights = """
  You are a helpful lighting system bot. You can turn
  lights on and off, and you can set the color. Do not perform any
  other tasks.
"""

# %%
chat = client.chats.create(
    model=MODEL_ID,
    config={
        'tools': light_controls,
        'system_instruction': instruction_lights,
    }
)

response = chat.send_message("It's awful dark in here...")
print(response.text)

# Tampilkan riwayat percakapan lengkap — perhatikan ada 'function_call' dan 'function_response'
print_history(chat)
# Out:
# LIGHTBOT: Lights enabled.
# It should be much brighter now! Let me know if you need anything else.
# ### user:
# It's awful dark in here...
# --------------------------------------------------------------------------------
# ### model:
# Function call: { id=None args={} name='enable_lights' partial_args=None will_continue=None }
# --------------------------------------------------------------------------------
# ### user:
# Function response: { will_continue=None scheduling=None parts=None id=None name='enable_lights' response={'result': None} }
# --------------------------------------------------------------------------------
# ### model:
# It should be much brighter now! Let me know if you need anything else.
# --------------------------------------------------------------------------------

# %% [markdown]
# # Function Calling — Version 2: Integrasi dengan Exa Web Search
#
# Di contoh sebelumnya, tool yang kita buat bersifat statis (logika sudah hardcoded di fungsi). Sekarang kita akan integrasikan **tool eksternal** — yaitu **Exa**, sebuah layanan web search berbasis AI.
#
# ### Apa itu Exa?
#
# **Exa** (exa.ai) adalah search engine yang dirancang khusus untuk dipakai oleh AI. Berbeda dengan Google Search biasa, Exa:
# - Mendukung **pencarian semantik** (mencari berdasarkan makna, bukan hanya keyword)
# - Mengembalikan **konten lengkap** dari halaman web, bukan hanya snippet
# - Dirancang untuk dikonsumsi LLM secara programatik
#
# **Kenapa Exa dan bukan Google Search?**
# Google Search API memerlukan setup yang lebih kompleks (Google Cloud Console, billing, dll). Exa menyediakan free tier yang cukup untuk eksperimen dan onboarding lebih mudah.
#
# ### Cara mendapatkan API Key Exa
#
# 1. Buka [https://exa.ai](https://exa.ai) dan buat akun (bisa pakai Google)
# 2. Masuk ke dashboard → bagian **API Keys**
# 3. Generate API key baru
# 4. Di Google Colab: klik ikon 🔑 (Secrets) di sidebar kiri → tambahkan secret dengan nama `EXA` dan paste API key-nya
#
# > **Catatan**: Exa memiliki **free tier** dengan kuota terbatas. Cukup untuk belajar dan eksperimen.

# %%
# %pip install -q exa-py
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 3.1 MB/s eta 0:00:00

# %%
from exa_py import Exa
from google.colab import userdata

# Simpan API key Exa di: Colab Secrets (🔑) → nama secret: EXA
EXA = userdata.get('EXA')
exa = Exa(api_key=EXA)

print('Exa client berhasil dibuat!')
# Out:
# Exa client berhasil dibuat!

# %% [markdown]
# ## Baseline: Gemini Tanpa Tool
#
# Sebelum kita integrasikan Exa, kita lihat dulu bagaimana Gemini menjawab pertanyaan tentang **berita lokal terkini** tanpa akses ke internet. Ini adalah perbandingan penting — kamu akan melihat Gemini mengakui keterbatasannya atau memberikan jawaban yang tidak akurat.

# %%
# Gemini tanpa tool → tidak tahu berita real-time
chat_tanpa_tool = client.chats.create(model=MODEL_ID)

response = chat_tanpa_tool.send_message('apa penyebab terjadinya demo di pati, jawa tengah?')
print(response.text)
print_history(chat_tanpa_tool)
# Out:
# Penyebab paling terkenal dan sering menjadi fokus demonstrasi di Pati, Jawa Tengah, adalah terkait **penolakan pembangunan pabrik semen dan penambangan karst di Pegunungan Kendeng**.
#
# Berikut adalah poin-poin penyebab utama dari isu tersebut:
#
# 1.  **Ancaman terhadap Sumber Mata Air:** Pegunungan Kendeng adalah daerah karst yang kaya akan gua-gua, sungai bawah tanah, dan mata air. Masyarakat, khususnya petani, sangat bergantung pada sumber air ini untuk mengairi sawah dan kebutuhan sehari-hari. Penambangan karst dikhawatirkan akan merusak ekosistem ini dan menyebabkan kekeringan.
# 2.  **Dampak Lingkungan:** Selain ancaman kekeringan, penambangan dan pembangunan pabrik semen juga dikhawatirkan akan menyebabkan kerusakan lingkungan lainnya seperti polusi udara dan air, hilangnya keanekaragaman hayati, dan perubahan bentang alam.
# 3.  **Ancaman terhadap Mata Pencarian Petani:** Mayoritas penduduk di sekitar Pegunungan Kendeng adalah petani. Rusaknya sumber air dan lahan pertanian akibat aktivitas penambangan akan langsung mengancam keberlangsungan hidup dan mata pencarian mereka.
# 4.  **Nilai Spiritual dan Budaya:** Bagi sebagian masyarakat adat di Kendeng, pegunungan ini memiliki nilai spiritual dan budaya yang tinggi. Merusak gunung dianggap melanggar tradisi dan keyakinan mereka.
# 5.  **Kurangnya Partisipasi Masyarakat:** Seringkali masyarakat merasa bahwa keputusan terkait izin penambangan atau pembangunan pabrik diambil tanpa melibatkan partisipasi aktif mereka atau tanpa mempertimbangkan aspirasi dan kekhawatiran mereka secara memadai.
#
# **Selain isu semen**, demonstrasi di Pati, seperti di daerah lain, juga bisa dipicu oleh berbagai masalah lain, seperti:
#
# *   **Sengketa Lahan:** Konflik kepemilikan atau penggunaan lahan antara masyarakat dengan perusahaan atau pemerintah.
# *   **Masalah Lingkungan Lain:** Pencemaran limbah industri, kerusakan hutan, atau isu-isu lingkungan lokal lainnya.
# *   **Kesejahteraan Masyarakat:** Tuntutan kenaikan upah, masalah ketenagakerjaan, atau protes terhadap kebijakan yang dianggap merugikan ekonomi rakyat.
# *   **Kebijakan Pemerintah Daerah:** Penolakan terhadap peraturan daerah atau keputusan pemerintah yang dianggap tidak pro-rakyat.
# *   **Isu Sosial/Politik:** Misalnya, protes terkait pelayanan publik yang buruk, korupsi, atau isu-isu politik lokal.

# --------------------------------------------------------------------------------

# %% [markdown]
# ## Solusi: Gemini + Exa sebagai Web Search Tool
#
# Sekarang kita berikan Gemini akses ke internet melalui fungsi `exa_search_and_contents`. Fungsi ini akan kita daftarkan sebagai tool — model akan memanggilnya secara otomatis saat butuh informasi terkini.

# %%
instruction_exa = """
You are a helpful and knowledgeable AI research assistant.
Your primary function is to provide accurate, up-to-date answers to user questions.

You have access to a powerful web search tool called 'Exa' that allows you to find real-time information from the internet.

**Your instructions are as follows:**

1.  **Analyze the User's Query:** First, understand the user's question.
    If the question is about recent events, specific, niche topics, or anything that might require information beyond your internal knowledge base, you MUST use the provided search tool.

2.  **Use the Search Tool (`exa_search_and_contents`):**
    * Formulate a clear and concise search `query` that best captures the user's intent.
    * Do not just repeat the user's question as the query. Synthesize it into effective search keywords.

3.  **Process the Search Results:**
    * Carefully read and synthesize the information from the provided content to construct your final answer.
    * Do not just copy the content. Explain it in your own words.

4.  **Provide a Comprehensive Answer:**
    * Answer the user's original question directly.
    * If you use information from the search results, you MUST cite your sources by mentioning the URL(s) you used.
    * If the search tool does not return relevant information, clearly state that you were unable to find the information. Do not invent an answer.
"""

# %%
def exa_search_and_contents(query: str):
    """
    Searches the internet for up-to-date information using a query.

    Args:
        query: A clear and concise search query string.

    Returns:
        A formatted string of search results including title, URL, and content snippet.
    """
    print(f"🔍 Executing Exa search for: '{query}'")
    try:
        search_results = exa.search_and_contents(
            query=query,
            type='auto',
            num_results=3,
            text={'max_characters': 2000}
        )

        formatted_results = []
        for result in search_results.results:
            formatted_results.append(
                f'Title: {result.title}\n'
                f'URL: {result.url}\n'
                f'Content: {result.text}\n'
                '-----------------'
            )

        return '\n'.join(formatted_results)

    except Exception as e:
        return f'An error occurred during the search: {e}'

# %%
# Chat dengan Exa sebagai tool — model akan otomatis memanggil exa_search_and_contents
chat_dengan_exa = client.chats.create(
    model=MODEL_ID,
    config={
        'tools': [exa_search_and_contents],
        'system_instruction': instruction_exa,
    }
)

response = chat_dengan_exa.send_message('apa penyebab terjadinya demo di pati, jawa tengah?')
print(response.text)

# Di history kamu akan melihat: function_call ke exa_search_and_contents,
# lalu function_response berisi hasil search, lalu model memberikan jawaban final
print_history(chat_dengan_exa)
# Out:
# 🔍 Executing Exa search for: 'penyebab demo pati jawa tengah'
# Penyebab utama terjadinya demo di Pati, Jawa Tengah, adalah protes terhadap kenaikan Pajak Bumi dan Bangunan Perdesaan dan Perkotaan (PBB P2) yang melonjak hingga 250%, serta pengenaan pajak untuk pedagang kaki lima (PKL).
#
# Selain itu, masyarakat juga menuntut Bupati Pati, Sudewo, untuk mundur dari jabatannya karena dianggap arogan dalam memimpin. Tuntutan lainnya termasuk:
# *   Protes terhadap program Regrouping Sekolah.
# *   Protes atas pemberhentian ratusan pegawai honorer RSUD Soewondo.
# *   Protes terhadap program lima hari sekolah.
#
# Aksi demo ini terjadi sekitar bulan Agustus 2025, dengan puncaknya pada 13 Agustus 2025, dan terus berlanjut hingga Februari 2026.
#
# Sumber:
# *   https://kompaspedia.kompas.id/baca/infografik/kronologi/demo-pati-2025-dari-pajak-melonjak-hingga-tuntutan-mundur-bupati
# *   https://www.bisnis.com/read/20250813/638/1901846/terungkap-tuntutan-demo-besar-di-pati-hari-ini-imbas-pajak-naik-250
